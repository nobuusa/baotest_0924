# %%
from docx import Document

# %%
doc = Document('baobao.docx')

# %%
for i, row in enumerate(doc.tables[0].rows):
    for j, cell in enumerate(row.cells):
        print(i, j, cell.text)
# Out:
# 0 0 A0
# 0 1 流水號
# 0 2
# 1 0 A1
# 1 1 （考卷+題目ID）
# 1 2 109F4LG00T2M2527M01
# 2 0 A2
# 2 1 年分
# 2 2 109
# 3 0 A3
# 3 1 等級
# 3 2 普考
# 4 0 A4
# 4 1 類科
# 4 2 一般民政
# 5 0 A5
# 5 1 科目
# 5 2 地方自治概要
# 6 0 A6
# 6 1 題號
# 6 2 1
# 7 0 A7
# 7 1 題目類型
# 7 2 單選題
# 8 0 A8
# 8 1 （題幹）
# 8 2 1 下列地方自治團體，何者非屬地方制度法明定應致力於公共造產之對象？ (A)直轄市 (B)縣（市） (C)鄉 (D)鎮
# 9 0 B1
# 9 1 （選項）
# 9 2
# 10 0 B2
# 10 1 A
# 10 2
# 11 0 B3
# 11 1 B
# 11 2
# 12 0 B4
# 12 1 C
# 12 2
# 13 0 B5
# 13 1 D
# 13 2
# 14 0 C1
# 14 1 標準答案
# 14 2 (A)
# 15 0 C2
# 15 1 更正
# 15 2
# 16 0 D1
# 16 1 （出處／法源）
# 16 2
# 17 0 D2
# 17 1 1
# 17 2 丘昌泰，2020，地方政府與自治，台北，三民，3版
# 18 0 D3
# 18 1 2
# 18 2
# 19 0 D4
# 19 1 3
# 19 2
# 20 0 D5
# 20 1 4
# 20 2
# 21 0 D6
# 21 1 5
# 21 2
# 22 0 E1
# 22 1 （關鍵字）
# 22 2
# 23 0 E2
# 23 1 1
# 23 2 直轄市議會議決之自治法規
# 24 0 E3
# 24 1 2
# 24 2 牴觸上位階法令
# 25 0 E4
# 25 1 3
# 25 2 覆議
# 26 0 E5
# 26 1 4
# 26 2 函告無效
# 27 0 E6
# 27 1 5
# 27 2 自治監督原則
# 28 0 F1
# 28 1 （單元架構）
# 28 2
# 29 0 F2
# 29 1 1
# 29 2 1
# 30 0 F3
# 30 1 2
# 30 2 4
# ...
